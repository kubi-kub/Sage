# %% [markdown]
# Wykres1

# %%
var("y")
contour_plot( x^2 + y^2, (x, -5, 5), (y, -5, 5),
fill=False, axes=True, labels=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 2

# %%
var("y")
contour_plot( x^2 - y^2, (x, -5, 5), (y, -5, 5),
fill=False, axes=True, labels=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 3

# %%
var("y")
contour_plot( x^2-y^2, (x, -10, 10), (y, -10, 10), plot_points=200)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 4

# %%
var("y")
contour_plot(x^4 + (y)^4/2, (x, -10, 10), (y, -10, 10),
fill=False, axes=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 5

# %%
var("y")
contour_plot(x^4 + (y)^4/2, (x, -10, 10), (y, -10, 10),
fill=True, axes=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Zastosowanie w mikroekonomii

# %% [markdown]
# Wykres 6

# %%
var("y")
contour_plot( 1400*x^0.51*y^0.32, (x, 0, 160), (y, 0, 160),
plot_points=300)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 7

# %%
var("y")
contour_plot( 1400*x^0.51*y^0.32, (x, 0, 160), (y, 0, 160),
fill=False, axes=True, labels=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 8

# %%
var("y")
contour_plot( 1400*x^0.99*y^0.01, (x, 0, 160), (y, 0, 160),
plot_points=300)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 9

# %%
var("y")
contour_plot( 1400*x^0.01*y^0.99, (x, 0, 160), (y, 0, 160),
plot_points=300)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wymuszanie określonych wartości

# %% [markdown]
# Wykres 10

# %%
var("y")
contour_plot(1400*x^0.51*y^0.32, (x, 0, 160), (y, 0, 160),
fill=False, axes=True, labels=True,
contours=[10000, 20000, 30000, 40000, 50000, 60000,
70000, 80000, 90000, 100000])
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Zastosowanie w termodynamice

# %% [markdown]
# Wykres 11

# %%
var("j t")
u(x, t) =  (80/pi)*sum(((1/(2*j+1))*exp(-(2*j+1)^2*pi^2*t/2500.0)*sin((2*j+1)*pi*x/50)), j, 0, 10)
plot( u(5, t), t, 0, 40, gridlines="minor")
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 12

# %%
var('j')
u(x, t) = (80/pi)*sum(((1/(2*j+1))*exp(-(2*j+1)^2*pi^2*t/2500.0)*sin((2*j+1)*pi*x/50)), j, 0, 10)
plot(u(x, 300), x, 0, 50, gridlines="minor")
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Wykres 13

# %%
contour_plot( u(x,t), (x,0,50), (t,0,300), aspect_ratio=0.1,
colorbar=True )
# Out:
# Graphics object consisting of 1 graphics primitive
